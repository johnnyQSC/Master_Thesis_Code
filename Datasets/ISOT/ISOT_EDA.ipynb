# %%
import pandas as pd
import numpy as np

# %%
file=pd.read_csv('ISOT_Merge.csv')
file
# Out:
#                                                    title  \
# 0      Puerto Rico says will default on $779 million ...
# 1      Czech ANO party dips but keeps commanding lead...
# 2      LOL! SNARKY WHITE YAHOO Sports Writer TRASHES ...
# 3       Jimmy Kimmel Joins The Ladies Of ‘The View’ T...
# 4      MUSLIM ATHLETE Given “Hero’s Welcome” ARRESTED...
# ...                                                  ...
# 44893   Congressional Black Caucus Cries Foul Over Su...
# 44894  BUSTED! GUESS WHO DEFENDED The Senate’s Role I...
# 44895  THIS PICTURE OF HARRIET TUBMAN Should Be Used ...
# 44896  AWESOME! UK LEADER: Nothing on Earth could eve...
# 44897  U.S. tip-off helped Russia thwart 'major' terr...
#
#                                                     text       subject  \
# 0      SAN JUAN (Reuters) - Puerto Rico on Friday sai...  politicsNews
# 1      PRAGUE (Reuters) - Support for billionaire And...     worldnews
# ...

# %%
file.isna().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# label      0
# dtype: int64

# %%
file=file.drop(['subject','date'],axis=1)
file
# Out:
#                                                    title  \
# 0      Puerto Rico says will default on $779 million ...
# 1      Czech ANO party dips but keeps commanding lead...
# 2      LOL! SNARKY WHITE YAHOO Sports Writer TRASHES ...
# 3       Jimmy Kimmel Joins The Ladies Of ‘The View’ T...
# 4      MUSLIM ATHLETE Given “Hero’s Welcome” ARRESTED...
# ...                                                  ...
# 44893   Congressional Black Caucus Cries Foul Over Su...
# 44894  BUSTED! GUESS WHO DEFENDED The Senate’s Role I...
# 44895  THIS PICTURE OF HARRIET TUBMAN Should Be Used ...
# 44896  AWESOME! UK LEADER: Nothing on Earth could eve...
# 44897  U.S. tip-off helped Russia thwart 'major' terr...
#
#                                                     text  label
# 0      SAN JUAN (Reuters) - Puerto Rico on Friday sai...      0
# 1      PRAGUE (Reuters) - Support for billionaire And...      0
# 2      How very bold of the white Yahoo sports writer...      1
# ...

# %%
file.to_csv('ISOT_EDA.csv',index=False,encoding='utf-8')
